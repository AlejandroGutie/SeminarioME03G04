# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroGutie/SeminarioME03G04/blob/main_1/Desnutrici%C3%B3n_e_inseguridad_alimentaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seminario de Analítica y Ciencia de Datos
# ### Momento Evaluativo 03
# ## _Aplicación de Ciencia de datos sobre la desnutrición e inseguridad alimentaria en los municipios de Antioquia en el marco del segundo Objetivo de Desarrollo Sostenible, 2013 - 2022_
#
# **Grupo 04**\
# Huberth Rolando Hincapié Arango\
# Yeisson Alejandro Gutiérrez Cano

# %% [markdown]
# # Herramientas

# %% [markdown]
# ## Librerías

# %%
# Datos
# ==============================================================================
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import seaborn as sns
#import matplotlib.pyplot as plt
#from matplotlib import style
#import missingno as msno

# Matemáticas y estadísticas
# ==============================================================================
import math

# Exportar datos
# ==============================================================================
from google.colab import files

# %% [markdown]
# # Procesamiento de datos

# %% [markdown]
# ## Importación de datos desde repositorio de GitHub

# %%
# Se importan los datos directamente desde el repositorio de Github
Indicators = pd.read_csv('https://raw.githubusercontent.com/AlejandroGutie/SeminarioME03G04/main/Indicadoresdesnutricioneinseguridadalimentaria.csv')

# Visualización del conjunto de datos
Indicators
# Out:
#      Desagregación Código subregión  Subregión  Código entidad  \
# 0        Municipal             SR08   Suroeste            5091
# 1        Municipal             SR08   Suroeste            5368
# 2        Municipal             SR06  Occidente            5044
# 3        Municipal             SR05      Norte            5086
# 4        Municipal             SR06  Occidente            5761
# ...            ...              ...        ...             ...
# 1245     Municipal             SR04   Nordeste            5604
# 1246     Municipal             SR08   Suroeste            5282
# 1247     Municipal             SR07    Oriente            5148
# 1248     Municipal             SR06  Occidente            5042
# 1249     Municipal             SR05      Norte            5264
#
#                     Entidad     Pilar  Número ODS   Nombre ODS  Número meta  \
# 0                   Betania  Personas           2  Hambre cero          2.1
# 1                    Jericó  Personas           2  Hambre cero          2.1
# 2                      Anzá  Personas           2  Hambre cero          2.1
# 3                   Belmira  Personas           2  Hambre cero          2.1
# 4                  Sopetrán  Personas           2  Hambre cero          2.1
# ...                     ...       ...         ...          ...          ...
# 1245               Remedios  Personas           2  Hambre cero          2.2
# 1246               Fredonia  Personas           2  Hambre cero          2.2
# 1247   El Carmen de Viboral  Personas           2  Hambre cero          2.2
# 1248  Santa Fé de Antioquia  Personas           2  Hambre cero          2.2
# 1249             Entrerríos  Personas           2  Hambre cero          2.2
#
#                                             Nombre meta Número indicador  \
# 0     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 1     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 2     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 3     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 4     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# ...                                                 ...              ...
# 1245      Terminar con todas las formas de desnutrición          2.2.2.P
# 1246      Terminar con todas las formas de desnutrición          2.2.2.P
# 1247      Terminar con todas las formas de desnutrición          2.2.2.P
# 1248      Terminar con todas las formas de desnutrición          2.2.2.P
# 1249      Terminar con todas las formas de desnutrición          2.2.2.P
#
#                                               Indicador       Valor  \
# 0     Prevalencia de inseguridad alimentaria en el h...    9.811121
# 1     Prevalencia de inseguridad alimentaria en el h...    4.609214
# 2     Prevalencia de inseguridad alimentaria en el h...   10.446802
# 3     Prevalencia de inseguridad alimentaria en el h...    4.360848
# 4     Prevalencia de inseguridad alimentaria en el h...   13.956997
# ...                                                 ...         ...
# 1245  Incidencia de desnutrición aguda en población ...   96.587250
# 1246  Incidencia de desnutrición aguda en población ...    0.000000
# 1247  Incidencia de desnutrición aguda en población ...   60.253063
# 1248  Incidencia de desnutrición aguda en población ...  924.024641
# 1249  Incidencia de desnutrición aguda en población ...  105.708245
#
#        Numerador  Denominador   Año  \
# 0     281.735355  2871.591928  2017
# 1     212.530844  4611.000000  2017
# 2     273.340949  2616.503497  2017
# 3      86.126742  1975.000000  2017
# 4     959.822660  6877.000000  2017
# ...          ...          ...   ...
# 1245    3.000000  3106.000000  2019
# 1246    0.000000  1383.000000  2019
# 1247    3.000000  4979.000000  2019
# 1248   18.000000  1948.000000  2019
# 1249    1.000000   946.000000  2019
#
#                                                  Fuente  \
# 0     DAP - Departamento Administrativo de Planeació...
# 1     DAP - Departamento Administrativo de Planeació...
# 2     DAP - Departamento Administrativo de Planeació...
# 3     DAP - Departamento Administrativo de Planeació...
# 4     DAP - Departamento Administrativo de Planeació...
# ...                                                 ...
# 1245  MinSalud - Sistema de Información para la Vigi...
# 1246  MinSalud - Sistema de Información para la Vigi...
# 1247  MinSalud - Sistema de Información para la Vigi...
# 1248  MinSalud - Sistema de Información para la Vigi...
# 1249  MinSalud - Sistema de Información para la Vigi...
#
#                         Unidad de medida
# 0                             Porcentaje
# 1                             Porcentaje
# 2                             Porcentaje
# 3                             Porcentaje
# 4                             Porcentaje
# ...                                  ...
# 1245  Tasa por 100 mil menores de 5 años
# 1246  Tasa por 100 mil menores de 5 años
# 1247  Tasa por 100 mil menores de 5 años
# 1248  Tasa por 100 mil menores de 5 años
# 1249  Tasa por 100 mil menores de 5 años
#
# [1250 rows x 18 columns]

# %%
# Se importan los datos directamente desde el repositorio de Github
Indicators2 = pd.read_csv('https://raw.githubusercontent.com/AlejandroGutie/SeminarioME03G04/main_1/Indicadores%20adicionales.csv')

# Visualización del conjunto de datos
Indicators2
# Out:
#      Desagregación Código subregión        Subregión  Código entidad  \
# 0        Municipal             SR07          Oriente            5321
# 1        Municipal             SR01  Valle de Aburrá            5631
# 2        Municipal             SR03  Magdalena Medio            5579
# 3        Municipal             SR07          Oriente            5376
# 4        Municipal             SR08         Suroeste            5847
# ...            ...              ...              ...             ...
# 4245     Municipal             SR06        Occidente            5628
# 4246     Municipal             SR01  Valle de Aburrá            5266
# 4247     Municipal             SR03  Magdalena Medio            5579
# 4248     Municipal             SR01  Valle de Aburrá            5631
# 4249     Municipal             SR09            Urabá            5665
#
#                  Entidad        Pilar  Número ODS  \
# 0                Guatapé     Personas           4
# 1               Sabaneta     Personas           4
# 2          Puerto Berrío     Personas           4
# 3      La Ceja del Tambo     Personas           4
# 4                  Urrao     Personas           4
# ...                  ...          ...         ...
# 4245         Sabanalarga  Prosperidad           7
# 4246            Envigado  Prosperidad           7
# 4247       Puerto Berrío  Prosperidad           7
# 4248            Sabaneta  Prosperidad           7
# 4249  San Pedro de Urabá  Prosperidad           7
#
#                                Nombre ODS  Número meta  \
# 0                    Educación de calidad          4.3
# 1                    Educación de calidad          4.3
# 2                    Educación de calidad          4.3
# 3                    Educación de calidad          4.3
# 4                    Educación de calidad          4.3
# ...                                   ...          ...
# 4245  Energía asequible y no contaminante          7.1
# 4246  Energía asequible y no contaminante          7.1
# 4247  Energía asequible y no contaminante          7.1
# 4248  Energía asequible y no contaminante          7.1
# 4249  Energía asequible y no contaminante          7.1
#
#                                             Nombre meta Número indicador  \
# 0     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 1     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 2     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 3     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 4     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# ...                                                 ...              ...
# 4245              Acceso universal a la energía moderna          7.1.1.C
# 4246              Acceso universal a la energía moderna          7.1.1.C
# 4247              Acceso universal a la energía moderna          7.1.1.C
# 4248              Acceso universal a la energía moderna          7.1.1.C
# 4249              Acceso universal a la energía moderna          7.1.1.C
#
#                                          Indicador       Valor  Numerador  \
# 0                  Cobertura en educación superior    6.616541       44.0
# 1                  Cobertura en educación superior   99.945464     5498.0
# 2                  Cobertura en educación superior   31.174993     1117.0
# 3                  Cobertura en educación superior   12.952030      702.0
# 4                  Cobertura en educación superior    6.606171      182.0
# ...                                            ...         ...        ...
# 4245  Cobertura de viviendas con energía eléctrica  100.000000     3502.0
# 4246  Cobertura de viviendas con energía eléctrica  100.000000    76963.0
# 4247  Cobertura de viviendas con energía eléctrica  100.000000    12431.0
# 4248  Cobertura de viviendas con energía eléctrica  100.000000    29426.0
# 4249  Cobertura de viviendas con energía eléctrica  100.000000     7813.0
#
#       Denominador   Año                                             Fuente  \
# 0           665.0  2013  MinEducación - Sistema Nacional de Información...
# 1          5501.0  2013  MinEducación - Sistema Nacional de Información...
# 2          3583.0  2013  MinEducación - Sistema Nacional de Información...
# 3          5420.0  2013  MinEducación - Sistema Nacional de Información...
# 4          2755.0  2013  MinEducación - Sistema Nacional de Información...
# ...           ...   ...                                                ...
# 4245       3502.0  2015  UPME - Unidad de Planeación Minero Energética-...
# 4246      76963.0  2015  UPME - Unidad de Planeación Minero Energética-...
# 4247      12431.0  2015  UPME - Unidad de Planeación Minero Energética-...
# 4248      29426.0  2015  UPME - Unidad de Planeación Minero Energética-...
# 4249       7813.0  2020  UPME - Unidad de Planeación Minero Energética-...
#
#      Unidad de medida
# 0          Porcentaje
# 1          Porcentaje
# 2          Porcentaje
# 3          Porcentaje
# 4          Porcentaje
# ...               ...
# 4245       Porcentaje
# 4246       Porcentaje
# 4247       Porcentaje
# 4248       Porcentaje
# 4249       Porcentaje
#
# [4250 rows x 18 columns]

# %% [markdown]
# ## Listado de variables

# %%
# Visualizamos las variables contenidas en el conjunto de datos
Indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Desagregación     1250 non-null   object
#  1   Código subregión  1250 non-null   object
#  2   Subregión         1250 non-null   object
#  3   Código entidad    1250 non-null   int64
#  4   Entidad           1250 non-null   object
#  5   Pilar             1250 non-null   object
#  6   Número ODS        1250 non-null   int64
#  7   Nombre ODS        1250 non-null   object
#  8   Número meta       1250 non-null   float64
#  9   Nombre meta       1250 non-null   object
#  10  Número indicador  1250 non-null   object
#  11  Indicador         1250 non-null   object
#  12  Valor             1250 non-null   float64
#  13  Numerador         1250 non-null   float64
#  14  Denominador       1250 non-null   float64
#  15  Año               1250 non-null   int64
#  16  Fuente            1250 non-null   object
#  17  Unidad de medida  1250 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 175.9+ KB

# %%
# Visualizamos las variables contenidas en el conjunto de datos
Indicators2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Desagregación     4250 non-null   object
#  1   Código subregión  4250 non-null   object
#  2   Subregión         4250 non-null   object
#  3   Código entidad    4250 non-null   int64
#  4   Entidad           4250 non-null   object
#  5   Pilar             4250 non-null   object
#  6   Número ODS        4250 non-null   int64
#  7   Nombre ODS        4250 non-null   object
#  8   Número meta       4250 non-null   float64
#  9   Nombre meta       4250 non-null   object
#  10  Número indicador  4250 non-null   object
#  11  Indicador         4250 non-null   object
#  12  Valor             4250 non-null   float64
#  13  Numerador         4250 non-null   float64
#  14  Denominador       4250 non-null   float64
#  15  Año               4250 non-null   int64
#  16  Fuente            4250 non-null   object
#  17  Unidad de medida  4250 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 597.8+ KB

# %% [markdown]
# ## Completitud del conjunto de datos

# %%
# Visualización con mapa de calor de los datos perdidos para las variables contenidas en el conjunto de datos
sns.heatmap(Indicators.isnull())
# Out:
# <Axes: >

# %%
# Visualización con mapa de calor de los datos perdidos para las variables contenidas en el conjunto de datos
sns.heatmap(Indicators2.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Variables categóricas

# %%
# Identificación de las variables categóricas
catCols = Indicators.select_dtypes(include = ["object"]).columns.tolist()
Indicators[catCols]
# Out:
#      Desagregación Código subregión  Subregión                Entidad  \
# 0        Municipal             SR08   Suroeste                Betania
# 1        Municipal             SR08   Suroeste                 Jericó
# 2        Municipal             SR06  Occidente                   Anzá
# 3        Municipal             SR05      Norte                Belmira
# 4        Municipal             SR06  Occidente               Sopetrán
# ...            ...              ...        ...                    ...
# 1245     Municipal             SR04   Nordeste               Remedios
# 1246     Municipal             SR08   Suroeste               Fredonia
# 1247     Municipal             SR07    Oriente   El Carmen de Viboral
# 1248     Municipal             SR06  Occidente  Santa Fé de Antioquia
# 1249     Municipal             SR05      Norte             Entrerríos
#
#          Pilar   Nombre ODS  \
# 0     Personas  Hambre cero
# 1     Personas  Hambre cero
# 2     Personas  Hambre cero
# 3     Personas  Hambre cero
# 4     Personas  Hambre cero
# ...        ...          ...
# 1245  Personas  Hambre cero
# 1246  Personas  Hambre cero
# 1247  Personas  Hambre cero
# 1248  Personas  Hambre cero
# 1249  Personas  Hambre cero
#
#                                             Nombre meta Número indicador  \
# 0     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 1     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 2     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 3     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# 4     Acceso universal a alimentos seguros y nutrici...          2.1.1.P
# ...                                                 ...              ...
# 1245      Terminar con todas las formas de desnutrición          2.2.2.P
# 1246      Terminar con todas las formas de desnutrición          2.2.2.P
# 1247      Terminar con todas las formas de desnutrición          2.2.2.P
# 1248      Terminar con todas las formas de desnutrición          2.2.2.P
# 1249      Terminar con todas las formas de desnutrición          2.2.2.P
#
#                                               Indicador  \
# 0     Prevalencia de inseguridad alimentaria en el h...
# 1     Prevalencia de inseguridad alimentaria en el h...
# 2     Prevalencia de inseguridad alimentaria en el h...
# 3     Prevalencia de inseguridad alimentaria en el h...
# 4     Prevalencia de inseguridad alimentaria en el h...
# ...                                                 ...
# 1245  Incidencia de desnutrición aguda en población ...
# 1246  Incidencia de desnutrición aguda en población ...
# 1247  Incidencia de desnutrición aguda en población ...
# 1248  Incidencia de desnutrición aguda en población ...
# 1249  Incidencia de desnutrición aguda en población ...
#
#                                                  Fuente  \
# 0     DAP - Departamento Administrativo de Planeació...
# 1     DAP - Departamento Administrativo de Planeació...
# 2     DAP - Departamento Administrativo de Planeació...
# 3     DAP - Departamento Administrativo de Planeació...
# 4     DAP - Departamento Administrativo de Planeació...
# ...                                                 ...
# 1245  MinSalud - Sistema de Información para la Vigi...
# 1246  MinSalud - Sistema de Información para la Vigi...
# 1247  MinSalud - Sistema de Información para la Vigi...
# 1248  MinSalud - Sistema de Información para la Vigi...
# 1249  MinSalud - Sistema de Información para la Vigi...
#
#                         Unidad de medida
# 0                             Porcentaje
# 1                             Porcentaje
# 2                             Porcentaje
# 3                             Porcentaje
# 4                             Porcentaje
# ...                                  ...
# 1245  Tasa por 100 mil menores de 5 años
# 1246  Tasa por 100 mil menores de 5 años
# 1247  Tasa por 100 mil menores de 5 años
# 1248  Tasa por 100 mil menores de 5 años
# 1249  Tasa por 100 mil menores de 5 años
#
# [1250 rows x 11 columns]

# %%
# Identificación de las variables categóricas
catCols = Indicators2.select_dtypes(include = ["object"]).columns.tolist()
Indicators2[catCols]
# Out:
#      Desagregación Código subregión        Subregión             Entidad  \
# 0        Municipal             SR07          Oriente             Guatapé
# 1        Municipal             SR01  Valle de Aburrá            Sabaneta
# 2        Municipal             SR03  Magdalena Medio       Puerto Berrío
# 3        Municipal             SR07          Oriente   La Ceja del Tambo
# 4        Municipal             SR08         Suroeste               Urrao
# ...            ...              ...              ...                 ...
# 4245     Municipal             SR06        Occidente         Sabanalarga
# 4246     Municipal             SR01  Valle de Aburrá            Envigado
# 4247     Municipal             SR03  Magdalena Medio       Puerto Berrío
# 4248     Municipal             SR01  Valle de Aburrá            Sabaneta
# 4249     Municipal             SR09            Urabá  San Pedro de Urabá
#
#             Pilar                           Nombre ODS  \
# 0        Personas                 Educación de calidad
# 1        Personas                 Educación de calidad
# 2        Personas                 Educación de calidad
# 3        Personas                 Educación de calidad
# 4        Personas                 Educación de calidad
# ...           ...                                  ...
# 4245  Prosperidad  Energía asequible y no contaminante
# 4246  Prosperidad  Energía asequible y no contaminante
# 4247  Prosperidad  Energía asequible y no contaminante
# 4248  Prosperidad  Energía asequible y no contaminante
# 4249  Prosperidad  Energía asequible y no contaminante
#
#                                             Nombre meta Número indicador  \
# 0     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 1     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 2     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 3     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# 4     Igualdad de acceso a educación técnica- vocaci...          4.3.1.C
# ...                                                 ...              ...
# 4245              Acceso universal a la energía moderna          7.1.1.C
# 4246              Acceso universal a la energía moderna          7.1.1.C
# 4247              Acceso universal a la energía moderna          7.1.1.C
# 4248              Acceso universal a la energía moderna          7.1.1.C
# 4249              Acceso universal a la energía moderna          7.1.1.C
#
#                                          Indicador  \
# 0                  Cobertura en educación superior
# 1                  Cobertura en educación superior
# 2                  Cobertura en educación superior
# 3                  Cobertura en educación superior
# 4                  Cobertura en educación superior
# ...                                            ...
# 4245  Cobertura de viviendas con energía eléctrica
# 4246  Cobertura de viviendas con energía eléctrica
# 4247  Cobertura de viviendas con energía eléctrica
# 4248  Cobertura de viviendas con energía eléctrica
# 4249  Cobertura de viviendas con energía eléctrica
#
#                                                  Fuente Unidad de medida
# 0     MinEducación - Sistema Nacional de Información...       Porcentaje
# 1     MinEducación - Sistema Nacional de Información...       Porcentaje
# 2     MinEducación - Sistema Nacional de Información...       Porcentaje
# 3     MinEducación - Sistema Nacional de Información...       Porcentaje
# 4     MinEducación - Sistema Nacional de Información...       Porcentaje
# ...                                                 ...              ...
# 4245  UPME - Unidad de Planeación Minero Energética-...       Porcentaje
# 4246  UPME - Unidad de Planeación Minero Energética-...       Porcentaje
# 4247  UPME - Unidad de Planeación Minero Energética-...       Porcentaje
# 4248  UPME - Unidad de Planeación Minero Energética-...       Porcentaje
# 4249  UPME - Unidad de Planeación Minero Energética-...       Porcentaje
#
# [4250 rows x 11 columns]

# %% [markdown]
# ## Variables numéricas

# %%
# Identificación de las varibles numéricas
numCols = Indicators.select_dtypes(include = ['float64','int64']).columns.tolist()
Indicators[numCols]
# Out:
#       Código entidad  Número ODS  Número meta       Valor   Numerador  \
# 0               5091           2          2.1    9.811121  281.735355
# 1               5368           2          2.1    4.609214  212.530844
# 2               5044           2          2.1   10.446802  273.340949
# 3               5086           2          2.1    4.360848   86.126742
# 4               5761           2          2.1   13.956997  959.822660
# ...              ...         ...          ...         ...         ...
# 1245            5604           2          2.2   96.587250    3.000000
# 1246            5282           2          2.2    0.000000    0.000000
# 1247            5148           2          2.2   60.253063    3.000000
# 1248            5042           2          2.2  924.024641   18.000000
# 1249            5264           2          2.2  105.708245    1.000000
#
#       Denominador   Año
# 0     2871.591928  2017
# 1     4611.000000  2017
# 2     2616.503497  2017
# 3     1975.000000  2017
# 4     6877.000000  2017
# ...           ...   ...
# 1245  3106.000000  2019
# 1246  1383.000000  2019
# 1247  4979.000000  2019
# 1248  1948.000000  2019
# 1249   946.000000  2019
#
# [1250 rows x 7 columns]

# %%
# Identificación de las varibles numéricas
numCols = Indicators2.select_dtypes(include = ['float64','int64']).columns.tolist()
Indicators2[numCols]
# Out:
#       Código entidad  Número ODS  Número meta       Valor  Numerador  \
# 0               5321           4          4.3    6.616541       44.0
# 1               5631           4          4.3   99.945464     5498.0
# 2               5579           4          4.3   31.174993     1117.0
# 3               5376           4          4.3   12.952030      702.0
# 4               5847           4          4.3    6.606171      182.0
# ...              ...         ...          ...         ...        ...
# 4245            5628           7          7.1  100.000000     3502.0
# 4246            5266           7          7.1  100.000000    76963.0
# 4247            5579           7          7.1  100.000000    12431.0
# 4248            5631           7          7.1  100.000000    29426.0
# 4249            5665           7          7.1  100.000000     7813.0
#
#       Denominador   Año
# 0           665.0  2013
# 1          5501.0  2013
# 2          3583.0  2013
# 3          5420.0  2013
# 4          2755.0  2013
# ...           ...   ...
# 4245       3502.0  2015
# 4246      76963.0  2015
# 4247      12431.0  2015
# 4248      29426.0  2015
# 4249       7813.0  2020
#
# [4250 rows x 7 columns]

# %% [markdown]
# # Definición de conjunto de datos

# %%
# Se seleccionan las variables definitivas para el conjunto de datos
indicators_select = Indicators[['Código entidad','Entidad','Indicador','Valor','Año',]]
indicators_select
# Out:
#       Código entidad                Entidad  \
# 0               5091                Betania
# 1               5368                 Jericó
# 2               5044                   Anzá
# 3               5086                Belmira
# 4               5761               Sopetrán
# ...              ...                    ...
# 1245            5604               Remedios
# 1246            5282               Fredonia
# 1247            5148   El Carmen de Viboral
# 1248            5042  Santa Fé de Antioquia
# 1249            5264             Entrerríos
#
#                                               Indicador       Valor   Año
# 0     Prevalencia de inseguridad alimentaria en el h...    9.811121  2017
# 1     Prevalencia de inseguridad alimentaria en el h...    4.609214  2017
# 2     Prevalencia de inseguridad alimentaria en el h...   10.446802  2017
# 3     Prevalencia de inseguridad alimentaria en el h...    4.360848  2017
# 4     Prevalencia de inseguridad alimentaria en el h...   13.956997  2017
# ...                                                 ...         ...   ...
# 1245  Incidencia de desnutrición aguda en población ...   96.587250  2019
# 1246  Incidencia de desnutrición aguda en población ...    0.000000  2019
# 1247  Incidencia de desnutrición aguda en población ...   60.253063  2019
# 1248  Incidencia de desnutrición aguda en población ...  924.024641  2019
# 1249  Incidencia de desnutrición aguda en población ...  105.708245  2019
#
# [1250 rows x 5 columns]

# %%
# Se seleccionan las variables definitivas para el conjunto de datos
indicators2_select = Indicators2[['Código entidad','Entidad','Indicador','Valor','Año',]]
indicators2_select
# Out:
#       Código entidad             Entidad  \
# 0               5321             Guatapé
# 1               5631            Sabaneta
# 2               5579       Puerto Berrío
# 3               5376   La Ceja del Tambo
# 4               5847               Urrao
# ...              ...                 ...
# 4245            5628         Sabanalarga
# 4246            5266            Envigado
# 4247            5579       Puerto Berrío
# 4248            5631            Sabaneta
# 4249            5665  San Pedro de Urabá
#
#                                          Indicador       Valor   Año
# 0                  Cobertura en educación superior    6.616541  2013
# 1                  Cobertura en educación superior   99.945464  2013
# 2                  Cobertura en educación superior   31.174993  2013
# 3                  Cobertura en educación superior   12.952030  2013
# 4                  Cobertura en educación superior    6.606171  2013
# ...                                            ...         ...   ...
# 4245  Cobertura de viviendas con energía eléctrica  100.000000  2015
# 4246  Cobertura de viviendas con energía eléctrica  100.000000  2015
# 4247  Cobertura de viviendas con energía eléctrica  100.000000  2015
# 4248  Cobertura de viviendas con energía eléctrica  100.000000  2015
# 4249  Cobertura de viviendas con energía eléctrica  100.000000  2020
#
# [4250 rows x 5 columns]

# %%
# Se construye el conjunto de datos definitivo
dataset = pd.concat([indicators_select, indicators2_select], axis=0).reset_index()
dataset
# Out:
#       index  Código entidad             Entidad  \
# 0         0            5091             Betania
# 1         1            5368              Jericó
# 2         2            5044                Anzá
# 3         3            5086             Belmira
# 4         4            5761            Sopetrán
# ...     ...             ...                 ...
# 5495   4245            5628         Sabanalarga
# 5496   4246            5266            Envigado
# 5497   4247            5579       Puerto Berrío
# 5498   4248            5631            Sabaneta
# 5499   4249            5665  San Pedro de Urabá
#
#                                               Indicador       Valor   Año
# 0     Prevalencia de inseguridad alimentaria en el h...    9.811121  2017
# 1     Prevalencia de inseguridad alimentaria en el h...    4.609214  2017
# 2     Prevalencia de inseguridad alimentaria en el h...   10.446802  2017
# 3     Prevalencia de inseguridad alimentaria en el h...    4.360848  2017
# 4     Prevalencia de inseguridad alimentaria en el h...   13.956997  2017
# ...                                                 ...         ...   ...
# 5495       Cobertura de viviendas con energía eléctrica  100.000000  2015
# 5496       Cobertura de viviendas con energía eléctrica  100.000000  2015
# 5497       Cobertura de viviendas con energía eléctrica  100.000000  2015
# 5498       Cobertura de viviendas con energía eléctrica  100.000000  2015
# 5499       Cobertura de viviendas con energía eléctrica  100.000000  2020
#
# [5500 rows x 6 columns]

# %%
# Descrición del dataset
dataset.describe()
# Out:
#              index  Código entidad        Valor          Año
# count  5500.000000     5500.000000  5500.000000  5500.000000
# mean   1783.590909     5415.744000    72.926176  2016.681818
# std    1260.214915      279.752383   130.659285     3.410007
# min       0.000000     5001.000000     0.000000  2010.000000
# 25%     687.000000     5147.000000     5.593700  2014.000000
# 50%    1499.500000     5376.000000    47.003653  2017.000000
# 75%    2874.250000     5659.000000   100.000000  2019.250000
# max    4249.000000     5895.000000  3533.568905  2022.000000

# %%
# Se exportan los datos estructurados en el dataset como un arcvhivo plano CSV
dataset.to_csv('dataset_municipios-DN.csv')
files.download('dataset_municipios-DN.csv')
